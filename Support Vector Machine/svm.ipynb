# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# %%
breast_cancer_df =load_breast_cancer()

# %%
breast_cancer_df.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
X = pd.DataFrame(breast_cancer_df["data"],columns=breast_cancer_df.feature_names)
y=breast_cancer_df["target"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = svm.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93        67
#            1       0.94      0.99      0.96       121
#
#     accuracy                           0.95       188
#    macro avg       0.96      0.94      0.95       188
# weighted avg       0.95      0.95      0.95       188

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 59   8]
#  [  1 120]]

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'kernel':['linear', 'rbf'], 'C':[1, 10],
              'gamma':[0.2,20,10,23]}

svc = SVC() 
clf = GridSearchCV(estimator=svc, param_grid=parameters,scoring='accuracy',cv=5,verbose=4)

# %%
clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END .....C=1, gamma=0.2, kernel=linear;, score=0.961 total time=   1.8s
# [CV 2/5] END .....C=1, gamma=0.2, kernel=linear;, score=0.934 total time=   0.5s
# [CV 3/5] END .....C=1, gamma=0.2, kernel=linear;, score=0.961 total time=   1.8s
# [CV 4/5] END .....C=1, gamma=0.2, kernel=linear;, score=0.974 total time=   2.1s
# [CV 5/5] END .....C=1, gamma=0.2, kernel=linear;, score=0.908 total time=   1.1s
# [CV 1/5] END ........C=1, gamma=0.2, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=20, kernel=linear;, score=0.961 total time=   1.3s
# [CV 2/5] END ......C=1, gamma=20, kernel=linear;, score=0.934 total time=   0.4s
# [CV 3/5] END ......C=1, gamma=20, kernel=linear;, score=0.961 total time=   1.2s
# [CV 4/5] END ......C=1, gamma=20, kernel=linear;, score=0.974 total time=   1.7s
# [CV 5/5] END ......C=1, gamma=20, kernel=linear;, score=0.908 total time=   1.1s
# [CV 1/5] END .........C=1, gamma=20, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=10, kernel=linear;, score=0.961 total time=   1.6s
# [CV 2/5] END ......C=1, gamma=10, kernel=linear;, score=0.934 total time=   0.4s
# [CV 3/5] END ......C=1, gamma=10, kernel=linear;, score=0.961 total time=   1.1s
# [CV 4/5] END ......C=1, gamma=10, kernel=linear;, score=0.974 total time=   1.6s
# [CV 5/5] END ......C=1, gamma=10, kernel=linear;, score=0.908 total time=   1.1s
# [CV 1/5] END .........C=1, gamma=10, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=23, kernel=linear;, score=0.961 total time=   1.2s
# [CV 2/5] END ......C=1, gamma=23, kernel=linear;, score=0.934 total time=   0.4s
# [CV 3/5] END ......C=1, gamma=23, kernel=linear;, score=0.961 total time=   1.1s
# [CV 4/5] END ......C=1, gamma=23, kernel=linear;, score=0.974 total time=   1.4s
# [CV 5/5] END ......C=1, gamma=23, kernel=linear;, score=0.908 total time=   1.0s
# [CV 1/5] END .........C=1, gamma=23, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.2, kernel=linear;, score=0.935 total time=   6.3s
# [CV 2/5] END ....C=10, gamma=0.2, kernel=linear;, score=0.974 total time=   6.7s
# [CV 3/5] END ....C=10, gamma=0.2, kernel=linear;, score=0.961 total time=   3.2s
# [CV 4/5] END ....C=10, gamma=0.2, kernel=linear;, score=0.974 total time=   7.0s
# [CV 5/5] END ....C=10, gamma=0.2, kernel=linear;, score=0.895 total time=   3.1s
# [CV 1/5] END .......C=10, gamma=0.2, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.2, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=20, kernel=linear;, score=0.935 total time=   6.3s
# [CV 2/5] END .....C=10, gamma=20, kernel=linear;, score=0.974 total time=   7.4s
# [CV 3/5] END .....C=10, gamma=20, kernel=linear;, score=0.961 total time=   4.8s
# [CV 4/5] END .....C=10, gamma=20, kernel=linear;, score=0.974 total time=   7.3s
# [CV 5/5] END .....C=10, gamma=20, kernel=linear;, score=0.895 total time=   3.5s
# [CV 1/5] END ........C=10, gamma=20, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=20, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=10, kernel=linear;, score=0.935 total time=   6.1s
# [CV 2/5] END .....C=10, gamma=10, kernel=linear;, score=0.974 total time=   6.6s
# [CV 3/5] END .....C=10, gamma=10, kernel=linear;, score=0.961 total time=   3.3s
# [CV 4/5] END .....C=10, gamma=10, kernel=linear;, score=0.974 total time=   7.6s
# [CV 5/5] END .....C=10, gamma=10, kernel=linear;, score=0.895 total time=   3.5s
# [CV 1/5] END ........C=10, gamma=10, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=10, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=23, kernel=linear;, score=0.935 total time=   6.3s
# [CV 2/5] END .....C=10, gamma=23, kernel=linear;, score=0.974 total time=   6.9s
# [CV 3/5] END .....C=10, gamma=23, kernel=linear;, score=0.961 total time=   3.4s
# [CV 4/5] END .....C=10, gamma=23, kernel=linear;, score=0.974 total time=   6.9s
# [CV 5/5] END .....C=10, gamma=23, kernel=linear;, score=0.895 total time=   3.8s
# [CV 1/5] END ........C=10, gamma=23, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=23, kernel=rbf;, score=0.618 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 10], 'gamma': [0.2, 20, 10, 23],
#                          'kernel': ['linear', 'rbf']},
#              scoring='accuracy', verbose=4)

# %%
clf.best_params_
# Out:
# {'C': 10, 'gamma': 0.2, 'kernel': 'linear'}

# %%
best_estimator = clf.best_estimator_

# %%
y_pred = best_estimator.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 63   4]
#  [  7 114]]
